# %%
# !pip install pandas numpy openpyxl sqlalchemy pymysql

# %%
# Import Required Libraries
import pandas as pd
import numpy as np

# %%
import os
print(os.getlogin())
# Out:
# user

# %%
import os

print(os.path.expanduser('~'))
# Out:
# C:\Users\user

# %%
import os

for root, dirs, files in os.walk(r'C:\Users\user'):
    if 'Ecommerce_Unclean_Project.xlsx' in files:
        print(os.path.join(root, 'Ecommerce_Unclean_Project.xlsx'))
# Out:
# C:\Users\user\Desktop\End to End Project\Ecommerce_Unclean_Project.xlsx

# %%
df = pd.read_excel(r'C:\Users\user\Desktop\End to End Project\Ecommerce_Unclean_Project.xlsx')

# %%
# Explore the Dataset
df.head()
# Out:
#   Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0  ORD1002  30-06-2025          Neha   neha82@gmail.com  9.829008e+09
# 1  ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9.280491e+09
# 2  ORD1004  06-05-2025          Amit    amit6@gmail.com  9.943311e+09
# 3  ORD1005  20-01-2025         Vikas  vikas51@gmail.com  9.495120e+09
# 4  ORD1006  02-04-2025         Rohit  rohit71@gmail.com  9.237332e+09
#
#         City        State Product     Category  Qty  Unit_Price Discount  \
# 0      Delhi        Delhi   Chair    Furniture  4.0      1999.0      NaN
# 1       Pune  Maharashtra   Watch      Fashion  5.0      4999.0       20
# 2     Jaipur    Rajasthan   Mouse  Electronics  3.0      1999.0        5
# 3  Bengaluru    Karnataka  Laptop  Electronics  NaN         NaN       15
# 4       Pune  Maharashtra  Bottle         Home  NaN      1999.0
#
#   Payment_Mode Order_Status Delivery_Date
# 0          UPI      Pending    03-07-2025
# ...

# %%
#View Information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       524 non-null    str
#  1   Order_Date     524 non-null    str
#  2   Customer_Name  524 non-null    str
#  3   Email          524 non-null    str
#  4   Phone          502 non-null    float64
#  5   City           524 non-null    str
#  6   State          524 non-null    str
#  7   Product        524 non-null    str
#  8   Category       524 non-null    str
#  9   Qty            457 non-null    float64
#  10  Unit_Price     471 non-null    float64
#  11  Discount       455 non-null    object
#  12  Payment_Mode   524 non-null    str
#  13  Order_Status   524 non-null    str
#  14  Delivery_Date  503 non-null    str
# dtypes: float64(3), object(1), str(11)
# memory usage: 107.3+ KB

# %%
#Statistical summary
df.describe()
# Out:
#               Phone         Qty   Unit_Price
# count  5.020000e+02  457.000000   471.000000
# mean   9.544725e+09    2.800875  3168.639066
# std    2.636920e+08    1.963974  2969.682209
# min    9.104441e+09   -1.000000   499.000000
# 25%    9.315673e+09    1.000000   999.000000
# 50%    9.533562e+09    3.000000  1999.000000
# 75%    9.792574e+09    5.000000  4999.000000
# max    9.999074e+09    5.000000  9999.000000

# %%
#Dataset Shape
df.shape
# Out:
# (524, 15)

# %%
# Check Missing Values
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_Name     0
# Email             0
# Phone            22
# City              0
# State             0
# Product           0
# Category          0
# Qty              67
# Unit_Price       53
# Discount         69
# Payment_Mode      0
# Order_Status      0
# Delivery_Date    21
# dtype: int64

# %%
#Check Duplicate Values
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
#Remove Duplicate Records
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Replace invalid values
df.replace(['N/A', '', 'NULL'],np.nan,inplace=True)
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9.829008e+09
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9.280491e+09
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9.943311e+09
# 3    ORD1005  20-01-2025         Vikas  vikas51@gmail.com  9.495120e+09
# 4    ORD1006  02-04-2025         Rohit  rohit71@gmail.com  9.237332e+09
# ..       ...         ...           ...                ...           ...
# 519  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9.789375e+09
# 520  ORD1609  2025/03/21         Rahul  rahul99@gmail.com  9.552650e+09
# 521  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9.700117e+09
# 522  ORD1611  11-01-2025          Neha   neha22@gmail.com  9.580304e+09
# 523  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9.551158e+09
#
#           City        State Product     Category  Qty  Unit_Price Discount  \
# ...

# %%
#Remove Extra Spaces
df = df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# %%
#Standardised text format
#Convert text into proper case

df['Customer_Name'] = df['Customer_Name'].str.title()
df['City'] = df['City'].str.title()
df['State'] = df['State'].str.title()

# %%
#Validate Email Addresses
#Keep Only Valid Emails

df = df[df['Email'].str.contains('@',na=False)]

# %%
#Convert Date Columns
df['Order_Date']=pd.to_datetime(df['Order_Date'],errors='coerce')
df['Delivery_Date']=pd.to_datetime(df['Delivery_Date'],errors='coerce')

# %%
print(pd.__version__)
# Out:
# 3.0.3

# %%
df['Order_Date'] = pd.to_datetime(
    df['Order_Date'],
    errors='coerce',
    dayfirst=True,
    format='mixed'
)

df['Delivery_Date'] = pd.to_datetime(
    df['Delivery_Date'],
    errors='coerce',
    dayfirst=True,
    format='mixed'
)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\user\Desktop\End to End Project\Ecommerce_Unclean_Project.xlsx')

# %%
# Convert Numeric Columns

cols = ['Qty', 'Unit_Price', 'Discount']

for c in cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# %%
#Remove Invalid Quantities 
#Remove zero or negative values

df= df[df['Qty']>0]

# %%
#Fill missing values

df['Discount'] = df['Discount'].fillna(0)

df['Phone'] = df['Phone'].fillna('Unknown')

df['Delivery_Date'] = df['Delivery_Date'].fillna(df['Order_Date'])

# %%
df['Sales'] = df['Qty'] * df['Unit_Price']

# %%
df
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...         ...           ...                ...           ...
# 519  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609  2025/03/21         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611  11-01-2025          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
#Net Amount


df['Net_Amount'] = df['Sales'] - (df['Sales'] * df['Discount'] / 100)

# %%
df
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...         ...           ...                ...           ...
# 519  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609  2025/03/21         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611  11-01-2025          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
# Profit (Ex 20% Profit)

df['Profit'] = df['Net_Amount'] * 0.20

# %%
df
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...         ...           ...                ...           ...
# 519  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609  2025/03/21         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611  11-01-2025          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
df
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...         ...           ...                ...           ...
# 519  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609  2025/03/21         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611  11-01-2025          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
df['Order_Date'] = pd.to_datetime(
    df['Order_Date'],
    errors='coerce',
    dayfirst=True
)

# %%
# Order Month

df['Month'] = df['Order_Date'].dt.month_name()

# %%
df
# Out:
#     Order_ID Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...        ...           ...                ...           ...
# 519  ORD1608 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609        NaT         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610 2025-04-10         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611 2025-01-11          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612 2025-03-03         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
# Order Year

df["Year"] = df["Order_Date"].dt.year

# %%
df
# Out:
#     Order_ID Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...        ...           ...                ...           ...
# 519  ORD1608 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609        NaT         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610 2025-04-10         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611 2025-01-11          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612 2025-03-03         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  Unit_Price  Discount  \
# ...

# %%
# Weekday

df['Weekday'] = df['Order_Date'].dt.day_name()

# %%
df
# Out:
#     Order_ID Order_Date Customer_Name              Email         Phone  \
# 0    ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0
# 1    ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0
# 2    ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0
# 5    ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0
# 6    ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# ..       ...        ...           ...                ...           ...
# 519  ORD1608 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0
# 520  ORD1609        NaT         Rahul  rahul99@gmail.com  9552649559.0
# 521  ORD1610 2025-04-10         Rohit  rohit96@gmail.com  9700116928.0
# 522  ORD1611 2025-01-11          Neha   neha22@gmail.com  9580304152.0
# 523  ORD1612 2025-03-03         Vikas  vikas46@gmail.com  9551158398.0
#
#         City        State Product     Category  Qty  ...  Discount  \
# ...

# %%
#Final Data Validation

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 402 entries, 0 to 523
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       402 non-null    str
#  1   Order_Date     353 non-null    datetime64[us]
#  2   Customer_Name  402 non-null    str
#  3   Email          402 non-null    str
#  4   Phone          402 non-null    object
#  5   City           402 non-null    str
#  6   State          402 non-null    str
#  7   Product        402 non-null    str
#  8   Category       402 non-null    str
#  9   Qty            402 non-null    float64
#  10  Unit_Price     363 non-null    float64
#  11  Discount       402 non-null    float64
#  12  Payment_Mode   402 non-null    str
#  13  Order_Status   402 non-null    str
#  14  Delivery_Date  402 non-null    str
#  15  Sales          363 non-null    float64
#  16  Net_Amount     363 non-null    float64
#  17  Profit         363 non-null    float64
# ...

# %%
# Check Missing Values

df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date       49
# Customer_Name     0
# Email             0
# Phone             0
# City              0
# State             0
# Product           0
# Category          0
# Qty               0
# Unit_Price       39
# Discount          0
# Payment_Mode      0
# Order_Status      0
# Delivery_Date     0
# Sales            39
# Net_Amount       39
# Profit           39
# Month            49
# Year             49
# Weekday          49
# dtype: int64

# %%
df.describe()
# Out:
#                        Order_Date         Qty   Unit_Price    Discount  \
# count                         353  402.000000   363.000000  402.000000
# mean   2025-04-02 17:52:51.671388    3.320896  3251.341598    7.823383
# min           2025-01-01 00:00:00    1.000000   499.000000    0.000000
# 25%           2025-02-14 00:00:00    2.000000   999.000000    0.000000
# 50%           2025-04-05 00:00:00    3.000000  1999.000000    5.000000
# 75%           2025-05-16 00:00:00    5.000000  4999.000000   15.000000
# max           2025-06-30 00:00:00    5.000000  9999.000000   20.000000
# std                           NaN    1.460711  3034.218072    7.922703
#
#               Sales    Net_Amount       Profit    Year
# count    363.000000    363.000000   363.000000   353.0
# mean   11115.680441  10260.530579  2052.106116  2025.0
# min      499.000000    399.200000    79.840000  2025.0
# 25%     2599.000000   2398.400000   479.680000  2025.0
# ...

# %%
# Step 16: Export Clean Data

df.to_csv('Clean_Ecommerce.csv', index=False)

# %%
# Step 17: Import Data into MySQL

from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:YOURPASSWORD@localhost/ecommerce')

# %%
# Export DataFrame to MySQL

df.to_sql(
    name='orders',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 402

# %%
df.shape
# Out:
# (402, 21)
